# %%
import pandas as pd

# %%
columns = ['Country', 'City', 'Latitude', 'Longitude', 'Temp', 'Humidity', 'Cloudiness', 'Windspeed', 'DateTime']
weather_df = pd.read_csv('cities.csv', names=columns)

# %%
print(weather_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country</th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Windspeed</th>
#       <th>DateTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>NaN</th>
#       <td>country</td>
#       <td>city</td>
#       <td>lat</td>
#       <td>lng</td>
#       <td>temp</td>
#       <td>humidity</td>
#       <td>cloudiness</td>
#       <td>wind speed</td>
#       <td>datetime</td>
#     </tr>
#     <tr>
#       <th>0.0</th>
#       <td>US</td>
#       <td>Jamestown</td>
#       <td>42.097</td>
#       <td>-79.2353</td>
#       <td>-7.78</td>
#       <td>73</td>
#       <td>1</td>
#       <td>3.09</td>
#       <td>1613085479</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>ZA</td>
#       <td>Cape Town</td>
#       <td>-33.9258</td>
# ...
